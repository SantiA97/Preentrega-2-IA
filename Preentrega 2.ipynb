# %% [raw]
# Preentrega 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nombre y apellido: Aita santiago
# Materia: IA y generación de prompts
#
#
#
#
#
#
# # Aplicación de Autoayuda para el Manejo del Estrés y Ansiedad en Estudiantes Universitarios
#
# Descripción de la problemática:
# El estrés y la ansiedad son problemas comunes entre los estudiantes universitarios, exacerbados por la presión académica, responsabilidades sociales y, en muchos casos, problemas financieros. Estos factores pueden llevar a una disminución del rendimiento académico y afectar negativamente la salud mental y emocional de los estudiantes.
#
#
#
# ##Propuesta de Solución:Aplicación de Autoayuda con Generación de Prompts
# Objetivo:
# Desarrollar una aplicación móvil que ofrezca herramientas de autoayuda mediante la generación de prompts que ayuden a los estudiantes a gestionar el estrés y la ansiedad. La aplicación proporcionará recursos para la reflexión personal, el desarrollo de habilidades de afrontamiento y la mejora del bienestar emocional.
# Funcionalidades de la Aplicación
# 1. **Generación de Prompts para el Diario Personal: Reflexión y Autoexploración**
# La aplicación podría incluir prompts que permitan a los estudiantes reflexionar sobre su estado emocional, sus pensamientos y sentimientos, y cómo gestionar sus emociones de manera constructiva.
# Modelo de Prompts para el Diario Personal:
# Reflexión sobre Estrés:
# "¿Qué situaciones de tu día te han generado más estrés? ¿Por qué crees que esas situaciones son tan difíciles de manejar?"
# "Si pudieras cambiar algo en tu rutina diaria para reducir el estrés, ¿qué cambiarías y cómo te gustaría que fuera?"
# "Hoy, piensa en algo que te haya generado ansiedad. ¿Cómo podrías verlo desde una perspectiva diferente para sentir menos presión?"
# Reflexión sobre Emociones y Sentimientos:
# "¿Qué emoción predominó en tu día? Identifica cómo te hizo sentir y qué pensamientos vinieron a tu mente."
# "Escribe una carta a tu 'yo futuro' describiendo cómo te sientes ahora y lo que esperas lograr en el próximo mes para mejorar tu bienestar emocional."
# "Escribe tres cosas por las que estás agradecido/a hoy. ¿Cómo te hace sentir la gratitud en momentos de estrés?"
# Autoaceptación y Autocompasión:
# "Piensa en un momento reciente cuando te sentiste frustrado/a contigo mismo/a. ¿Cómo podrías ser más amable contigo en esa situación?"
# "¿Qué palabras de apoyo le dirías a un amigo/a que está pasando por un momento difícil? Ahora, di esas mismas palabras para ti mismo/a."
#
#
# 2. **Ejercicios de Mindfulness y Técnicas de Relajación**
# Los ejercicios de mindfulness y relajación son muy eficaces para reducir el estrés y la ansiedad. Estos prompts pueden guiar a los estudiantes en la práctica de la atención plena y en la conexión con el momento presente.
# Modelo de Prompts para Mindfulness:
# Ejercicio de Respiración Profunda:
# "Dedica 3 minutos a respirar lentamente. Inhala profundamente durante 4 segundos, sostén por 4, exhala por 6. ¿Cómo te sientes antes y después de este ejercicio?"
# "Haz una pausa y toma 5 respiraciones profundas. ¿Qué cambios percibes en tu cuerpo o mente tras este ejercicio?"
# Escaneo Corporal para Relajación:
# "Haz un escaneo corporal mental, comenzando desde tus pies hasta tu cabeza. ¿En qué partes de tu cuerpo sientes tensión? Tómate un momento para liberar esa tensión con cada exhalación."
# "Cierra los ojos, respira profundamente y enfócate en cómo se sienten tus manos, tus piernas o tu rostro. ¿Hay alguna parte de tu cuerpo que necesite más atención o relajación?"
# Conexión con el Entorno:
# "Mira a tu alrededor y describe 5 cosas que puedes ver. Intenta observarlas como si las estuvieras viendo por primera vez. ¿Cómo cambia tu perspectiva al poner atención plena en ellas?"
# "Detente un momento y escucha el ambiente a tu alrededor. ¿Qué sonidos puedes identificar? Respira profundamente y enfócate solo en esos sonidos por unos minutos."
# 3. Establecimiento de Metas y Seguimiento del Progreso Emocional
# Fomentar que los estudiantes se establezcan metas realistas y hagan un seguimiento de su progreso es esencial para la gestión efectiva del estrés. Los prompts para metas pueden incluir tanto aspectos emocionales como prácticos.
# Modelo de Prompts para Metas y Progreso:
# Establecimiento de Metas:
# "¿Qué pequeñas metas puedes establecer para reducir tu estrés esta semana? ¿Cómo puedes hacerlas alcanzables?"
# "Define una meta personal que te ayude a sentirte más equilibrado/a (por ejemplo, hacer ejercicio, organizar tu tiempo). ¿Cómo puedes empezar a trabajar en ella hoy?"
# Reflexión sobre el Progreso:
# "Esta semana, ¿qué técnicas o hábitos has implementado para reducir el estrés? ¿Han funcionado? ¿Qué puedes mejorar?"
# "Reflexiona sobre un momento en el que lograste mantener la calma durante una situación estresante. ¿Qué estrategias utilizaste y cómo las puedes aplicar en situaciones futuras?"
# Evaluación de Logros:
# "Piensa en un momento reciente donde sentiste que manejaste bien el estrés. ¿Qué pasos tomaste para lograrlo? ¿Cómo puedes repetir esa experiencia?"
# "Hoy, escribe tres cosas que hayas hecho bien en el manejo de tu estrés.
#
#
# 4. **Comunidad de Apoyo y Motivación Colectiva**
# El apoyo social es fundamental para combatir el estrés y la ansiedad. Fomentar una comunidad de estudiantes que compartan sus experiencias y se motiven mutuamente puede ser muy beneficioso.
# Modelo de Prompts para la Comunidad de Apoyo:
# Compartir Estrategias y Consejos:
# "Comparte una estrategia que te haya ayudado a manejar el estrés en momentos de exámenes. ¿Cómo la aprendiste?"
# "¿Hay alguna técnica o hábito que te haya ayudado a sentirte menos ansioso/a durante la semana? Comparte tu experiencia para que otros puedan aprender."
# Reflexión Grupal sobre la Ansiedad Académica:
# "Muchos estudiantes experimentan ansiedad por los exámenes. ¿Cómo manejas la presión de los exámenes? Comparte tu mejor consejo para reducir esa ansiedad."
# "Si pudieras darle un consejo a alguien que se siente abrumado/a por las responsabilidades académicas, ¿qué le dirías?"
# Motivación y Empoderamiento:
# "Hoy, reflexiona sobre tus logros personales en medio de la ansiedad académica. ¿Qué has hecho que te llena de orgullo?"
# "Imagina que estás apoyando a un amigo/a que se siente muy ansioso/a. ¿Qué palabras de ánimo le dirías para ayudarlo/a a superar el día?"
#
#
# 5. **Recursos Adicionales: Contenido Educativo y Recomendaciones**
# El contenido educativo es clave para dar a los estudiantes más herramientas para enfrentar la ansiedad. Los prompts pueden sugerir artículos, videos, y otras herramientas dependiendo de lo que el estudiante necesite en el momento.
# Modelo de Prompts para Sugerencia de Recursos:
# Contenido Relacionado con Estrés Académico:
# "Parece que la carga académica te está afectando. Aquí tienes un artículo sobre cómo organizar tu tiempo de manera efectiva para reducir el estrés. ¿Te gustaría leerlo?"
# "Estás pasando por una semana difícil. ¿Te gustaría ver un video sobre técnicas para relajarte antes de los exámenes?"
# Recursos sobre Salud Mental y Autocuidado:
# "Hoy podría ser un buen día para aprender más sobre cómo establecer límites saludables. ¿Te gustaría leer un artículo sobre cómo decir 'no' sin sentir culpa?"
# "Parece que has tenido días difíciles últimamente. Aquí tienes un video sobre cómo incorporar prácticas de autocuidado en tu rutina diaria. ¿Te gustaría verlo?"
# Meditación y Mindfulness:
# "¿Te gustaría practicar una meditación guiada para reducir el estrés? Aquí tienes una opción que puedes hacer en 10 minutos."
# "Hoy te recomendamos una breve práctica de mindfulness que te ayudará a reducir la ansiedad. ¿Te gustaría intentarlo?"
#
#
# ##Evaluación del Impacto
# Para evaluar la efectividad de la aplicación, se pueden usar encuestas antes y después de su uso para medir cambios en los niveles de estrés y ansiedad de los estudiantes. También sería útil recopilar feedback sobre la utilidad de los prompts generados y su impacto en la salud mental.
# Justificación de la Viabilidad del Proyecto: Análisis Técnico
# La viabilidad técnica del proyecto es alta, con un equipo técnico calificado, el uso de tecnologías probadas y una planificación adecuada en términos de tiempo, presupuesto y recursos. El desarrollo ágil y la personalización de la aplicación garantizan que la solución se mantenga relevante y útil para los estudiantes universitarios, proporcionando una herramienta accesible para la gestión del estrés y la ansiedad. Con una inversión inicial moderada, la aplicación tiene el potencial de ser una solución escalable y sostenible a largo plazo.
#
#
# ##Conclusión
# Esta propuesta tiene el potencial de ofrecer una solución accesible y práctica para los estudiantes universitarios que luchan contra el estrés y la ansiedad. La combinación de tecnología y prompts creativos puede facilitar la autoexploración y el desarrollo de habilidades de afrontamiento, promoviendo así una mejor salud mental en el entorno académico.
#
# import openai
# import matplotlib.pyplot as plt
#
# openai.api_key = 'tu_api_key_aqui'  # reemplazar la api aca(con seguridad)
#
# prompts = {
#     "estrés": [
#         "¿Qué situaciones de tu día te han generado más estrés?",
#         "Si pudieras cambiar algo en tu rutina diaria para reducir el estrés, ¿qué cambiarías?"
#     ],
#     "mindfulness": [
#         "Dedica 3 minutos a respirar lentamente. Inhala profundamente durante 4 segundos...",
#         "Haz un escaneo corporal mental, comenzando desde tus pies hasta tu cabeza."
#     ]
# }
#
# def generar_respuesta(prompt, temperatura=0.7):
#     response = openai.Completion.create(
#         engine="text-davinci-003",
#         prompt=prompt,
#         max_tokens=150,
#         temperature=temperatura
#     )
#     return response.choices[0].text.strip()
#
# # respuestas
# respuestas = []
# for tema, lista_prompts in prompts.items():
#     for prompt in lista_prompts:
#         respuesta = generar_respuesta(prompt)
#         respuestas.append(respuesta)
#         print(f"Prompt: {prompt}\nRespuesta: {respuesta}\n{'-'*40}")
#
# # Análisis
# eficacia = [0.8, 0.85, 0.9]  # Este sería un ejemplo de datos
# etiquetas = ['Bajo', 'Medio', 'Alto']
#
# plt.bar(etiquetas, eficacia, color=['red', 'orange', 'green'])
# plt.title('Eficacia de Prompts')
# plt.ylabel('Proporción de Éxito')
# plt.show()
